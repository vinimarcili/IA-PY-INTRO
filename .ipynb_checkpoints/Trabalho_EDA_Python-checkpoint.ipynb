# %% [markdown]
# # Trabalho Final - Análise de Dados com Python
#
# Integrantes:
#
# 1) Vinicius - 345167
# 2) Guilherme - 346006
# 3) Fabiana - 345858

# %% [markdown]
# ### Enunciado
#
# A partir dos dados housing.csv, realize toda análise exploratória necessária e prepare os dados para algoritmos de machine learning usando a Scikit-Learn. Treine um modelo de regressão linear que prediga a variável meta (median_house_value) e cujo valor de RMSE seja menor ou igual a 69000.

# %%
# leitura dos dados
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
housing = pd.read_csv('bases/housing.csv')
housing.head()
# Out:
#    longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0    -122.23     37.88                41.0        880.0           129.0
# 1    -122.22     37.86                21.0       7099.0          1106.0
# 2    -122.24     37.85                52.0       1467.0           190.0
# 3    -122.25     37.85                52.0       1274.0           235.0
# 4    -122.25     37.85                52.0       1627.0           280.0
#
#    population  households  median_income  median_house_value ocean_proximity
# 0       322.0       126.0         8.3252            452600.0        NEAR BAY
# 1      2401.0      1138.0         8.3014            358500.0        NEAR BAY
# 2       496.0       177.0         7.2574            352100.0        NEAR BAY
# 3       558.0       219.0         5.6431            341300.0        NEAR BAY
# 4       565.0       259.0         3.8462            342200.0        NEAR BAY

# %%
# linhas e colunas
housing.shape
# Out:
# (20640, 10)

# %%
# tipos de dados
housing.dtypes
# Out:
# longitude             float64
# latitude              float64
# housing_median_age    float64
# total_rooms           float64
# total_bedrooms        float64
# population            float64
# households            float64
# median_income         float64
# median_house_value    float64
# ocean_proximity        object
# dtype: object

# %%
# estatísticas
housing.describe()
# Out:
#           longitude      latitude  housing_median_age   total_rooms  \
# count  20640.000000  20640.000000        20640.000000  20640.000000
# mean    -119.569704     35.631861           28.639486   2635.763081
# std        2.003532      2.135952           12.585558   2181.615252
# min     -124.350000     32.540000            1.000000      2.000000
# 25%     -121.800000     33.930000           18.000000   1447.750000
# 50%     -118.490000     34.260000           29.000000   2127.000000
# 75%     -118.010000     37.710000           37.000000   3148.000000
# max     -114.310000     41.950000           52.000000  39320.000000
#
#        total_bedrooms    population    households  median_income  \
# count    20433.000000  20640.000000  20640.000000   20640.000000
# mean       537.870553   1425.476744    499.539680       3.870671
# std        421.385070   1132.462122    382.329753       1.899822
# min          1.000000      3.000000      1.000000       0.499900
# 25%        296.000000    787.000000    280.000000       2.563400
# 50%        435.000000   1166.000000    409.000000       3.534800
# 75%        647.000000   1725.000000    605.000000       4.743250
# max       6445.000000  35682.000000   6082.000000      15.000100
#
#        median_house_value
# count        20640.000000
# mean        206855.816909
# std         115395.615874
# min          14999.000000
# 25%         119600.000000
# 50%         179700.000000
# 75%         264725.000000
# max         500001.000000

# %%
housing.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20640 entries, 0 to 20639
# Data columns (total 10 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   longitude           20640 non-null  float64
#  1   latitude            20640 non-null  float64
#  2   housing_median_age  20640 non-null  float64
#  3   total_rooms         20640 non-null  float64
#  4   total_bedrooms      20433 non-null  float64
#  5   population          20640 non-null  float64
#  6   households          20640 non-null  float64
#  7   median_income       20640 non-null  float64
#  8   median_house_value  20640 non-null  float64
#  9   ocean_proximity     20640 non-null  object
# dtypes: float64(9), object(1)
# memory usage: 1.6+ MB

# %%
# nulls
housing.isnull().sum()
# Out:
# longitude               0
# latitude                0
# housing_median_age      0
# total_rooms             0
# total_bedrooms        207
# population              0
# households              0
# median_income           0
# median_house_value      0
# ocean_proximity         0
# dtype: int64

# %%
# Add total_bedrooms when is null
housing['total_bedrooms'].fillna(housing['total_bedrooms'].mean(), inplace=True)
housing.isnull().sum()
# Out:
# longitude             0
# latitude              0
# housing_median_age    0
# total_rooms           0
# total_bedrooms        0
# population            0
# households            0
# median_income         0
# median_house_value    0
# ocean_proximity       0
# dtype: int64

# %%
# count value counts for each column
housing['ocean_proximity'].value_counts()
# Out:
# <1H OCEAN     9136
# INLAND        6551
# NEAR OCEAN    2658
# NEAR BAY      2290
# ISLAND           5
# Name: ocean_proximity, dtype: int64

# %%
# normalize ocean_proximity
housing['ocean_proximity'] = housing['ocean_proximity'].map({
    '<1H OCEAN': 1,
    'INLAND': 2,
    'NEAR OCEAN': 3,
    'NEAR BAY': 4,
    'ISLAND': 5
})
housing['ocean_proximity'].value_counts()
# Out:
# 1    9136
# 2    6551
# 3    2658
# 4    2290
# 5       5
# Name: ocean_proximity, dtype: int64

# %%
# Como só tem 5 valores em ISLAND, vamos remove-los
housing = housing.drop(housing[housing['ocean_proximity'] == 5].index)
housing['ocean_proximity'].value_counts()
# Out:
# 1    9136
# 2    6551
# 3    2658
# 4    2290
# Name: ocean_proximity, dtype: int64

# %%
# Media de pessoas por familia na região
housing['median_population_per_household'] = round(housing['population'] / housing['households'], 2)

# %%
# Média de comodos por Familia
housing['median_rooms_per_household'] = round(housing['total_rooms'] / housing['households'], 2)
# Média de quartos por Familia
housing['median_population_per_troms'] = round(housing['population'] / housing['total_rooms'], 2)
# Proporção de Populalção por familia
housing['median_population_per_tbedrooms'] = round(housing['population'] / housing['total_bedrooms'], 2)
# Média de alugule por idade da casa
housing['median_income_per_houseage'] = round(housing['median_income'] / housing['housing_median_age'], 2)
# Média de aluguél por total de quartos
housing['median_income_per_tbrooms'] = round(housing['median_income'] / housing['total_bedrooms'], 2)
#Média de aluguél por total de comodos
housing['median_income_per_trooms'] = round(housing['median_income'] / housing['total_rooms'], 2)
# Média de aluguél por familia
housing['median_income_per_households'] = round(housing['median_income'] / housing['households'], 2)
# Proporção de Comodos por Idade da casa
housing['median_trooms_per_houseage'] = round(housing['total_rooms'] / housing['housing_median_age'], 2)
#Proporção de Quartos por Idade da casa
housing['median_tbrooms_per_houseage'] = round(housing['total_bedrooms'] / housing['housing_median_age'], 2)

# %%
# Clusterizar por média da idade da casa
housing.loc[housing['housing_median_age'] <= 10, 'housing_age'] = 0
housing.loc[housing['housing_median_age'] > 10, 'housing_age'] = 1
housing.loc[housing['housing_median_age'] > 20, 'housing_age'] = 2
housing.loc[housing['housing_median_age'] > 30, 'housing_age'] = 3
housing.loc[housing['housing_median_age'] > 40, 'housing_age'] = 4
housing.loc[housing['housing_median_age'] > 50, 'housing_age'] = 5

# %%
housing.head()
# Out:
#    longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0    -122.23     37.88                41.0        880.0           129.0
# 1    -122.22     37.86                21.0       7099.0          1106.0
# 2    -122.24     37.85                52.0       1467.0           190.0
# 3    -122.25     37.85                52.0       1274.0           235.0
# 4    -122.25     37.85                52.0       1627.0           280.0
#
#    population  households  median_income  median_house_value  ocean_proximity  \
# 0       322.0       126.0         8.3252            452600.0                4
# 1      2401.0      1138.0         8.3014            358500.0                4
# 2       496.0       177.0         7.2574            352100.0                4
# 3       558.0       219.0         5.6431            341300.0                4
# 4       565.0       259.0         3.8462            342200.0                4
#
#    ...  median_population_per_troms  median_population_per_tbedrooms  \
# 0  ...                         0.37                             2.50
# 1  ...                         0.34                             2.17
# 2  ...                         0.34                             2.61
# 3  ...                         0.44                             2.37
# 4  ...                         0.35                             2.02
#
#    median_income_per_oceanprox  median_income_per_houseage  \
# 0                         2.08                        0.20
# 1                         2.08                        0.40
# 2                         1.81                        0.14
# 3                         1.41                        0.11
# 4                         0.96                        0.07
#
#    median_income_per_tbrooms  median_income_per_trooms  \
# 0                       0.06                      0.01
# 1                       0.01                      0.00
# 2                       0.04                      0.00
# 3                       0.02                      0.00
# 4                       0.01                      0.00
#
#    median_income_per_households  median_trooms_per_houseage  \
# 0                          0.07                       21.46
# 1                          0.01                      338.05
# 2                          0.04                       28.21
# 3                          0.03                       24.50
# 4                          0.01                       31.29
#
#    median_tbrooms_per_houseage  housing_age
# 0                         3.15          4.0
# 1                        52.67          2.0
# 2                         3.65          5.0
# 3                         4.52          5.0
# 4                         5.38          5.0
#
# [5 rows x 22 columns]

# %%
# Retirando multicolinearidade por correlação de pearson
housing.corr()
# Out:
#                                  longitude  latitude  housing_median_age  \
# longitude                         1.000000 -0.924676           -0.108394
# latitude                         -0.924676  1.000000            0.011462
# housing_median_age               -0.108394  0.011462            1.000000
# total_rooms                       0.044642 -0.036231           -0.361268
# total_bedrooms                    0.069304 -0.066741           -0.319033
# population                        0.099881 -0.108978           -0.296172
# households                        0.055400 -0.071199           -0.302863
# median_income                    -0.015090 -0.079977           -0.118949
# median_house_value               -0.046208 -0.143837            0.105272
# ocean_proximity                  -0.440849  0.392255            0.144550
# median_population_per_household   0.002484  0.002351            0.013216
# median_rooms_per_household       -0.027547  0.106420           -0.153437
# median_population_per_troms       0.005194 -0.004621            0.023271
# median_population_per_tbedrooms   0.000748  0.000600            0.014724
# median_income_per_oceanprox       0.228336 -0.309015           -0.109177
# median_income_per_houseage        0.054356 -0.043450           -0.552046
# median_income_per_tbrooms        -0.019384  0.011257            0.024092
# median_income_per_trooms         -0.013354  0.009747            0.018062
# median_income_per_households     -0.019752  0.014890            0.020978
# median_trooms_per_houseage        0.061730 -0.031185           -0.404397
# median_tbrooms_per_houseage       0.072593 -0.041633           -0.429912
# housing_age                      -0.108825  0.013152            0.979412
#
#                                  total_rooms  total_bedrooms  population  \
# longitude                           0.044642        0.069304    0.099881
# latitude                           -0.036231       -0.066741   -0.108978
# housing_median_age                 -0.361268       -0.319033   -0.296172
# total_rooms                         1.000000        0.927255    0.857117
# total_bedrooms                      0.927255        1.000000    0.873920
# population                          0.857117        0.873920    1.000000
# households                          0.918480        0.974737    0.907213
# median_income                       0.197991       -0.007725    0.004737
# median_house_value                  0.134373        0.049559   -0.024421
# ocean_proximity                    -0.015965       -0.021174   -0.083138
# median_population_per_household    -0.024592       -0.028363    0.069852
# median_rooms_per_household          0.133804        0.001527   -0.072207
# median_population_per_troms        -0.032885       -0.022355    0.061574
# median_population_per_tbedrooms    -0.023138       -0.029025    0.065995
# median_income_per_oceanprox         0.133171       -0.000667    0.039480
# median_income_per_houseage          0.345471        0.220368    0.206869
# median_income_per_tbrooms          -0.074943       -0.088941   -0.075384
# median_income_per_trooms           -0.079191       -0.085009   -0.070277
# median_income_per_households       -0.077469       -0.090706   -0.080843
# median_trooms_per_houseage          0.726157        0.632346    0.584283
# median_tbrooms_per_houseage         0.733048        0.690450    0.613571
# housing_age                        -0.342800       -0.303407   -0.282403
#
#                                  households  median_income  \
# longitude                          0.055400      -0.015090
# latitude                          -0.071199      -0.079977
# housing_median_age                -0.302863      -0.118949
# total_rooms                        0.918480       0.197991
# total_bedrooms                     0.974737      -0.007725
# population                         0.907213       0.004737
# households                         1.000000       0.012950
# median_income                      0.012950       1.000000
# median_house_value                 0.066069       0.688563
# ocean_proximity                   -0.026741      -0.039278
# median_population_per_household   -0.027323       0.018758
# median_rooms_per_household        -0.080596       0.326916
# median_population_per_troms       -0.019545      -0.011082
# median_population_per_tbedrooms   -0.022994       0.024336
# median_income_per_oceanprox        0.022199       0.733542
# median_income_per_houseage         0.209200       0.444807
# median_income_per_tbrooms         -0.088437       0.132329
# median_income_per_trooms          -0.086734       0.095907
# median_income_per_households      -0.093503       0.133415
# median_trooms_per_houseage         0.602346       0.128549
# median_tbrooms_per_houseage        0.653435       0.071429
# housing_age                       -0.288042      -0.109952
#
#                                  median_house_value  ocean_proximity  ...  \
# longitude                                 -0.046208        -0.440849  ...
# latitude                                  -0.143837         0.392255  ...
# housing_median_age                         0.105272         0.144550  ...
# total_rooms                                0.134373        -0.015965  ...
# total_bedrooms                             0.049559        -0.021174  ...
# population                                -0.024421        -0.083138  ...
# households                                 0.066069        -0.026741  ...
# median_income                              0.688563        -0.039278  ...
# median_house_value                         1.000000         0.020641  ...
# ocean_proximity                            0.020641         1.000000  ...
# median_population_per_household           -0.023720        -0.010258  ...
# median_rooms_per_household                 0.151971         0.019174  ...
# median_population_per_troms               -0.033544        -0.011391  ...
# median_population_per_tbedrooms           -0.018971        -0.010092  ...
# median_income_per_oceanprox                0.524288        -0.610986  ...
# median_income_per_houseage                 0.208130        -0.056884  ...
# median_income_per_tbrooms                  0.058826         0.019376  ...
# median_income_per_trooms                   0.035149         0.019708  ...
# median_income_per_households               0.058260         0.016941  ...
# median_trooms_per_houseage                 0.027851        -0.029439  ...
# median_tbrooms_per_houseage                0.000231        -0.032169  ...
# housing_age                                0.111268         0.147833  ...
#
#                                  median_population_per_troms  \
# longitude                                           0.005194
# latitude                                           -0.004621
# housing_median_age                                  0.023271
# total_rooms                                        -0.032885
# total_bedrooms                                     -0.022355
# population                                          0.061574
# households                                         -0.019545
# median_income                                      -0.011082
# median_house_value                                 -0.033544
# ocean_proximity                                    -0.011391
# median_population_per_household                     0.959564
# median_rooms_per_household                         -0.040896
# median_population_per_troms                         1.000000
# median_population_per_tbedrooms                     0.990760
# median_income_per_oceanprox                        -0.009462
# median_income_per_houseage                         -0.018838
# median_income_per_tbrooms                           0.129130
# median_income_per_trooms                            0.219432
# median_income_per_households                        0.110905
# median_trooms_per_houseage                         -0.015748
# median_tbrooms_per_houseage                        -0.014278
# housing_age                                         0.022225
#
#                                  median_population_per_tbedrooms  \
# longitude                                               0.000748
# latitude                                                0.000600
# housing_median_age                                      0.014724
# total_rooms                                            -0.023138
# total_bedrooms                                         -0.029025
# population                                              0.065995
# households                                             -0.022994
# median_income                                           0.024336
# median_house_value                                     -0.018971
# ocean_proximity                                        -0.010092
# median_population_per_household                         0.985901
# median_rooms_per_household                             -0.018137
# median_population_per_troms                             0.990760
# median_population_per_tbedrooms                         1.000000
# median_income_per_oceanprox                             0.013491
# median_income_per_houseage                             -0.001935
# median_income_per_tbrooms                               0.135329
# median_income_per_trooms                                0.217186
# median_income_per_households                            0.117550
# median_trooms_per_houseage                             -0.009117
# median_tbrooms_per_houseage                            -0.012270
# housing_age                                             0.013984
#
#                                  median_income_per_oceanprox  \
# longitude                                           0.228336
# latitude                                           -0.309015
# housing_median_age                                 -0.109177
# total_rooms                                         0.133171
# total_bedrooms                                     -0.000667
# population                                          0.039480
# households                                          0.022199
# median_income                                       0.733542
# median_house_value                                  0.524288
# ocean_proximity                                    -0.610986
# median_population_per_household                     0.008833
# median_rooms_per_household                          0.187552
# median_population_per_troms                        -0.009462
# median_population_per_tbedrooms                     0.013491
# median_income_per_oceanprox                         1.000000
# median_income_per_houseage                          0.325507
# median_income_per_tbrooms                           0.062259
# median_income_per_trooms                            0.037626
# median_income_per_households                        0.065947
# median_trooms_per_houseage                          0.083698
# median_tbrooms_per_houseage                         0.045528
# housing_age                                        -0.105321
#
#                                  median_income_per_houseage  \
# longitude                                          0.054356
# latitude                                          -0.043450
# housing_median_age                                -0.552046
# total_rooms                                        0.345471
# total_bedrooms                                     0.220368
# population                                         0.206869
# households                                         0.209200
# median_income                                      0.444807
# median_house_value                                 0.208130
# ocean_proximity                                   -0.056884
# median_population_per_household                   -0.001647
# median_rooms_per_household                         0.218038
# median_population_per_troms                       -0.018838
# median_population_per_tbedrooms                   -0.001935
# median_income_per_oceanprox                        0.325507
# median_income_per_houseage                         1.000000
# median_income_per_tbrooms                          0.042012
# median_income_per_trooms                           0.037220
# median_income_per_households                       0.053169
# median_trooms_per_houseage                         0.611356
# median_tbrooms_per_houseage                        0.578653
# housing_age                                       -0.519918
#
#                                  median_income_per_tbrooms  \
# longitude                                        -0.019384
# latitude                                          0.011257
# housing_median_age                                0.024092
# total_rooms                                      -0.074943
# total_bedrooms                                   -0.088941
# population                                       -0.075384
# households                                       -0.088437
# median_income                                     0.132329
# median_house_value                                0.058826
# ocean_proximity                                   0.019376
# median_population_per_household                   0.129560
# median_rooms_per_household                        0.028159
# median_population_per_troms                       0.129130
# median_population_per_tbedrooms                   0.135329
# median_income_per_oceanprox                       0.062259
# median_income_per_houseage                        0.042012
# median_income_per_tbrooms                         1.000000
# median_income_per_trooms                          0.887035
# median_income_per_households                      0.977598
# median_trooms_per_houseage                       -0.029787
# median_tbrooms_per_houseage                      -0.036100
# housing_age                                       0.024484
#
#                                  median_income_per_trooms  \
# longitude                                       -0.013354
# latitude                                         0.009747
# housing_median_age                               0.018062
# total_rooms                                     -0.079191
# total_bedrooms                                  -0.085009
# population                                      -0.070277
# households                                      -0.086734
# median_income                                    0.095907
# median_house_value                               0.035149
# ocean_proximity                                  0.019708
# median_population_per_household                  0.207033
# median_rooms_per_household                       0.001411
# median_population_per_troms                      0.219432
# median_population_per_tbedrooms                  0.217186
# median_income_per_oceanprox                      0.037626
# median_income_per_houseage                       0.037220
# median_income_per_tbrooms                        0.887035
# median_income_per_trooms                         1.000000
# median_income_per_households                     0.868205
# median_trooms_per_houseage                      -0.027241
# median_tbrooms_per_houseage                     -0.031066
# housing_age                                      0.018799
#
#                                  median_income_per_households  \
# longitude                                           -0.019752
# latitude                                             0.014890
# housing_median_age                                   0.020978
# total_rooms                                         -0.077469
# total_bedrooms                                      -0.090706
# population                                          -0.080843
# households                                          -0.093503
# median_income                                        0.133415
# median_house_value                                   0.058260
# ocean_proximity                                      0.016941
# median_population_per_household                      0.117681
# median_rooms_per_household                           0.072175
# median_population_per_troms                          0.110905
# median_population_per_tbedrooms                      0.117550
# median_income_per_oceanprox                          0.065947
# median_income_per_houseage                           0.053169
# median_income_per_tbrooms                            0.977598
# median_income_per_trooms                             0.868205
# median_income_per_households                         1.000000
# median_trooms_per_houseage                          -0.030355
# median_tbrooms_per_houseage                         -0.036577
# housing_age                                          0.021434
#
#                                  median_trooms_per_houseage  \
# longitude                                          0.061730
# latitude                                          -0.031185
# housing_median_age                                -0.404397
# total_rooms                                        0.726157
# total_bedrooms                                     0.632346
# population                                         0.584283
# households                                         0.602346
# median_income                                      0.128549
# median_house_value                                 0.027851
# ocean_proximity                                   -0.029439
# median_population_per_household                   -0.007710
# median_rooms_per_household                         0.110658
# median_population_per_troms                       -0.015748
# median_population_per_tbedrooms                   -0.009117
# median_income_per_oceanprox                        0.083698
# median_income_per_houseage                         0.611356
# median_income_per_tbrooms                         -0.029787
# median_income_per_trooms                          -0.027241
# median_income_per_households                      -0.030355
# median_trooms_per_houseage                         1.000000
# median_tbrooms_per_houseage                        0.982077
# housing_age                                       -0.378457
#
#                                  median_tbrooms_per_houseage  housing_age
# longitude                                           0.072593    -0.108825
# latitude                                           -0.041633     0.013152
# housing_median_age                                 -0.429912     0.979412
# total_rooms                                         0.733048    -0.342800
# total_bedrooms                                      0.690450    -0.303407
# population                                          0.613571    -0.282403
# households                                          0.653435    -0.288042
# median_income                                       0.071429    -0.109952
# median_house_value                                  0.000231     0.111268
# ocean_proximity                                    -0.032169     0.147833
# median_population_per_household                    -0.010284     0.012502
# median_rooms_per_household                          0.074278    -0.146042
# median_population_per_troms                        -0.014278     0.022225
# median_population_per_tbedrooms                    -0.012270     0.013984
# median_income_per_oceanprox                         0.045528    -0.105321
# median_income_per_houseage                          0.578653    -0.519918
# median_income_per_tbrooms                          -0.036100     0.024484
# median_income_per_trooms                           -0.031066     0.018799
# median_income_per_households                       -0.036577     0.021434
# median_trooms_per_houseage                          0.982077    -0.378457
# median_tbrooms_per_houseage                         1.000000    -0.403578
# housing_age                                        -0.403578     1.000000
#
# [22 rows x 22 columns]

# %%
# %matplotlib inline
sns.heatmap(housing.corr(),
            cmap='Blues'
           )
plt.title('Correlação de Pearson entre variáveis do dataset').figsize=(40,40)
plt.show()

# %%
# Scikit-Learn. Treine um modelo de regressão linear que prediga a variável meta (median_house_value) e cujo valor de RMSE seja menor ou igual a 69000. 
import numpy as np
from sklearn.linear_model import LinearRegression
lr = LinearRegression()
X_train = housing.drop(['median_house_value'], axis=1)
y_train = housing['median_house_value']
lr.fit(X_train, y_train)
round(lr.score(X_train, y_train) * 100, 2)
# Out:
# 64.38

# %%
# RSME #69440.13
from sklearn.metrics import mean_squared_error
housing_predictions = lr.predict(X_train)
housing_mse = mean_squared_error(y_train, housing_predictions)
housing_rmse = np.sqrt(housing_mse)
round(housing_rmse, 2)
# Out:
# 68851.27
